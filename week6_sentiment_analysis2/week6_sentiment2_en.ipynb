# %% [markdown]
# # 第六週: 英文文集的情緒分析2
#
# **Author:** 蔡睿澤<br>
# **Date created:** 2023/03/22<br>
# **Last modified:** 2023/03/25<br><br>
# 本週課程為「情緒分析2」，與情緒分析1不同，這次會使用corenlp自然語言處理工具包，此包含 Courpus-base 的情緒分析，不是使用情緒字典而是使用預訓練的情緒分析模型或演算法為整個文章給與一個情緒分數。情緒分析2的步驟會因所要分析之語言不同而有所差異，在這個Jupyter Notebook當中將會展示「英文」的情緒分析，並且搭配python程式碼進行講解。在後面的內容中會介紹coreNLP、分析方法、介紹一款用於情緒分析的套件TextBlob

# %% [markdown]
# ## 大綱
# 1. 套件說明
# 2. coreNLP 介紹
#     + 2.1 安裝coreNLP
#     + 2.2 利用coreNLP進行自然語言處理
#     + 2.3 利用coreNLP進行句法結構標註
# 3. 文章抓取 & coreNLP 標註
#     + 3.1 使用coreNLP進行實作
#     + 3.2 探索分析 - NER
#     + 3.3 探索分析 - Sentiment
# 4. TextBlob

# %% [markdown]
# ## 1. 套件說明
# 下面列出在本次實作過程中我們所使用到的相關套件，在這個Jupyter Notebook當中我們將會簡單的展示這些套件的使用方式，關於各個套件的進階使用請同學參照其官網的說明。
# - pandas: 一個資料分析的函式庫，提供了DataFrame等資料格式，與資料處理的函數。
# - NLTK: 全名為Natural Language Tool Kit，自然語言處理工具。
# - stanza: 使用CoreNLP的官方套件
# - wordcloud: 文字雲繪圖工具。
# - matplotlib: 繪圖工具。
# - textblob: TextBlob是一個用Python編寫的開源的文字處理庫。它可以用來執行很多自然語言處理的任務，比如，詞性標註，名詞性成分提取，情緒分析，文字翻譯

# %%
# 安裝會使用到的套件
# %pip install stanza ipywidgets wordcloud tweepy==3.10.0 textblob

# %%
# 確認當前工作目錄
# %pwd

# %%
import stanza
from stanza.server import CoreNLPClient
from ipywidgets import IntProgress

import os
import time
import pandas as pd

import tweepy as tw

from nltk.parse import CoreNLPParser
from nltk.parse.corenlp import *
from nltk.corpus import stopwords

from wordcloud import WordCloud, STOPWORDS

import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %% [markdown]
# 如果有重新裝package，記得需要restart kernel 才會使用更新後的套件

# %%
# 檢查推特api package 版本，建議使用 3.10.0
print(tw.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ## 2. coreNLP 介紹
# Stanford CoreNLP是Stanford大學NLP Group用Java開發的NLP工具，它支持很多中語言(包括中文)。整合了許多工具來實現斷詞、斷句、詞性標註、句法分析等許多常見的NLP任務。

# %% [markdown]
# ### 2.1 安裝coreNLP
# + 可以用stanza管理NLP的相關模型

# %%
stanza.install_corenlp("./stanza_corenlp") # 下載coreNLP模型，預設會在/stanza_corenlp裡面
# Out:
# 2023-03-25 19:55:01 WARNING: Directory ./stanza_corenlp already exists. Please install CoreNLP to a new directory.

# %%
os.environ['CORENLP_HOME'] = "./stanza_corenlp" # 因為自訂下載路徑，所以要設定環境參數

# %% [markdown]
# ### 開啟CoreNLP client 端
#
# + 每次使用CoreNLP套件就需要開啟Client
# + 可以設定相關的port和處理的memory大小
# + 記得每次開起來之後要把client關掉，可以用with語法確保每次執行完自己關掉
# + 不然會因為重複使用 port 出現`Error: unable to start the CoreNLP server on port XXX`的錯誤訊息
#
# 以下用簡單的範例說明

# %%
# 設定 CoreNLPClient with some basic annotators, a memory allocation of 4GB, and port number 9008
client = CoreNLPClient(
            # client要處理的項目
            annotators=['tokenize','ssplit','pos','lemma','ner','entitymentions', 'parse', 'sentiment'],     
            memory='4G', 
            endpoint='http://localhost:9008',
            be_quiet=True
        )

# Start the background server and wait for some time
# Note that in practice this is totally optional, as by default the server will be started when the first annotation is performed
client.start()
import time; time.sleep(5)
# Out:
# 2023-03-25 19:55:01 INFO: Writing properties to tmp file: corenlp_server-af04479030324ae7.props
# 2023-03-25 19:55:01 INFO: Starting server with command: java -Xmx4G -cp ./stanza_corenlp/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9008 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-af04479030324ae7.props -annotators tokenize,ssplit,pos,lemma,ner,entitymentions,parse,sentiment -preload -outputFormat serialized

# %% [markdown]
# 參數參考文件
# + https://stanfordnlp.github.io/stanza/client_properties.html

# %%
# 將要分析的字串傳入client，得到coreNLP的document object
text = 'Try this: Make united states united again. For more info of Stanford CoreNLP Server, please visit www.khalidalnajjar.com for more details'
document = client.annotate(text)
print(type(document))
# Out:
# <class 'CoreNLP_pb2.Document'>

# %% [markdown]
# ### 2.2 利用coreNLP進行自然語言處理
# 透過幾行code就可以實現斷詞、詞性標註、詞型還原、命名實體辨識
#
# 本次教材主要會用到的功能有以下幾個
# + [lemma](https://stanfordnlp.github.io/CoreNLP/lemma.html)：詞性還原，將字詞還原成原始的時態，如`was`還原成`be`
# + [POS](https://stanfordnlp.github.io/CoreNLP/pos.html)：詞性標註，標註字詞的詞性，如名詞、動詞等等
#     ([coreNLP doc](https://nlp.stanford.edu/software/tagger.shtml)、[Penn Treebank POS Tag Set](https://www.eecis.udel.edu/~vijay/cis889/ie/pos-set.pdf))
# + [NER](https://stanfordnlp.github.io/CoreNLP/ner.html)：命名實體辨識，可以識別句子中的實體，如人名、地名、組織名稱等等([coreNLP doc](https://stanfordnlp.github.io/stanza/available_models.html?fbclid=IwAR2-EaWW0H66i7YYqjovv4QNUslvuNoJQtGzZTHoKhA7tOBmUQ8FwcrfYwQ))

# %%
# text 會被分成個句子，用for迴圈把每個字取出來，看看對應的 lemma, pos and ner tags 標籤
print(f"{'Word':12s}\t{'Lemma':12s}\t{'POS':6s}\t{'NER'}\n{'-' * 50}")  

for i, sent in enumerate(document.sentence): 
    for t in sent.token:
        print("{:12s}\t{:12s}\t{:6s}\t{}".format(t.word, t.lemma, t.pos, t.ner))
    print("")
# Out:
# Word        	Lemma       	POS   	NER
# --------------------------------------------------
# Try         	try         	VB    	O
# this        	this        	DT    	O
# :           	:           	:     	O
# Make        	make        	VB    	O
# united      	united      	JJ    	COUNTRY
# states      	state       	NNS   	COUNTRY
# united      	unite       	VBD   	O
# again       	again       	RB    	O
# .           	.           	.     	O
#
# For         	for         	IN    	O
# more        	more        	JJR   	O
# info        	info        	NN    	O
# of          	of          	IN    	O
# Stanford    	Stanford    	NNP   	O
# CoreNLP     	corenlp     	NN    	O
# Server      	server      	NN    	O
# ,           	,           	,     	O
# please      	please      	UH    	O
# visit       	visit       	VB    	O
# www.khalidalnajjar.com	www.khalidalnajjar.com	ADD   	URL
# for         	for         	IN    	O
# more        	more        	JJR   	O
# details     	detail      	NNS   	O

# %% [markdown]
# 在NER的部分，有時候會出現人名、地名是名詞詞組，除了上面用單詞標註的ner，我們可以利用`entitymentions`把名詞詞組拿出來

# %%
for i, sent in enumerate(document.sentence): 
    print(f"{'Words':12s}\t{'NER'}\n{'-' * 50}")     
    for mention in sent.mentions:
        print(mention.entityMentionText, mention.ner)
    s = ""
    for t in sent.token: 
        s = s + t.word + " "
    print(f"sentence{i}: {s}\n")
# Out:
# Words       	NER
# --------------------------------------------------
# united states COUNTRY
# sentence0: Try this : Make united states united again .
#
# Words       	NER
# --------------------------------------------------
# www.khalidalnajjar.com URL
# sentence1: For more info of Stanford CoreNLP Server , please visit www.khalidalnajjar.com for more details

# %% [markdown]
# #### POS 小補充
# 同樣的詞可能會因為詞義不同而有不同的詞性，以下舉her這個詞為例，在第一句代替「她」這個人，所以是`PRP`，在第二句則是指「她的」所以分類為`PRP$`
# + 「her」的 POS 分類
#     + `PRP`:人稱代名詞(personal pronoun)，其他如 I, he, she
#     + `PRP$`: 所有代名詞(possessive pronoun)，其他如 my, his, hers

# %%
text = 'I didn\'t tell her. Do you know her name?'
document = client.annotate(text)
for i, sent in enumerate(document.sentence): 
    for t in sent.token:
        print("{:12s}\t{:12s}\t{:6s}\t{}".format(t.word, t.lemma, t.pos, t.ner))
    print("")
# Out:
# I           	I           	PRP   	O
# did         	do          	VBD   	O
# n't         	not         	RB    	O
# tell        	tell        	VB    	O
# her         	she         	PRP   	O
# .           	.           	.     	O
#
# Do          	do          	VBP   	O
# you         	you         	PRP   	O
# know        	know        	VB    	O
# her         	she         	PRP$  	O
# name        	name        	NN    	O
# ?           	?           	.     	O

# %% [markdown]
# ### 2.3  利用coreNLP進行句法結構標註(Dependency)

# %%
# 示範句法結構
for i, sent in enumerate(document.sentence):
    
    # get the constituency parse of the sentence
    constituency_parse = sent.parseTree # child 
    print(constituency_parse)

    # get the dependency parse of the first sentence
    dependency_parse = sent.basicDependencies # edge
    print(dependency_parse)
    break # 只顯示第一句!!
# Out:
# child {
#   child {
#     child {
#       child {
#         value: "I"
#       }
#       value: "PRP"
#       score: -1.9594900608062744
#     }
#     value: "NP"
#     score: -2.8210573196411133
#   }
#   child {
#     child {
#       child {
#         value: "did"
#       }
#       value: "VBD"
#       score: -3.213421106338501
#     }
#     child {
#       child {
#         value: "n\'t"
#       }
#       value: "RB"
#       score: -0.82838243246078491
#     }
#     child {
#       child {
#         child {
#           value: "tell"
#         }
#         value: "VB"
#         score: -5.0789213180541992
#       }
#       child {
#         child {
#           child {
#             value: "her"
#           }
#           value: "PRP"
#           score: -5.0322332382202148
#         }
#         value: "NP"
#         score: -6.9078340530395508
#       }
#       value: "VP"
#       score: -14.039284706115723
#     }
#     value: "VP"
#     score: -23.121818542480469
#   }
#   child {
#     child {
#       value: "."
#     }
#     value: "."
#     score: -0.057524647563695908
#   }
#   value: "S"
#   score: -27.136920928955078
# }
# value: "ROOT"
# score: -27.308300018310547
#
# node {
#   sentenceIndex: 0
#   index: 4
# }
# node {
#   sentenceIndex: 0
#   index: 1
# }
# node {
#   sentenceIndex: 0
#   index: 2
# }
# node {
#   sentenceIndex: 0
#   index: 3
# }
# node {
#   sentenceIndex: 0
#   index: 5
# }
# node {
#   sentenceIndex: 0
#   index: 6
# }
# edge {
#   source: 4
#   target: 1
#   dep: "nsubj"
#   isExtra: false
#   sourceCopy: 0
#   targetCopy: 0
#   language: UniversalEnglish
# }
# edge {
#   source: 4
#   target: 2
#   dep: "aux"
#   isExtra: false
#   sourceCopy: 0
#   targetCopy: 0
#   language: UniversalEnglish
# }
# edge {
#   source: 4
#   target: 3
#   dep: "advmod"
#   isExtra: false
#   sourceCopy: 0
#   targetCopy: 0
#   language: UniversalEnglish
# }
# edge {
#   source: 4
#   target: 5
#   dep: "obj"
#   isExtra: false
#   sourceCopy: 0
#   targetCopy: 0
#   language: UniversalEnglish
# }
# edge {
#   source: 4
#   target: 6
#   dep: "punct"
#   isExtra: false
#   sourceCopy: 0
#   targetCopy: 0
#   language: UniversalEnglish
# }
# root: 4

# %% [markdown]
# ### 2.4 利用coreNLP進行情緒標註(Sentiment)

# %%
document = client.annotate("I love this cheese sandwich, it’s so delicious. This chicken burger has a very bad taste")
print(f"{'Word':12s}\t{'Sentiment':12s}\n{'-' * 50}") 
for i, sent in enumerate(document.sentence):
    for t in sent.token:
        print("{:12s}\t{:12s}".format(t.word,t.sentiment))
    print(f"The sentiment of the {i}-th sentence is： {sent.sentiment}\n{'-' * 50}")
# Out:
# Word        	Sentiment
# --------------------------------------------------
# I           	Neutral
# love        	Very positive
# this        	Neutral
# cheese      	Neutral
# sandwich    	Neutral
# ,           	Neutral
# it          	Neutral
# ’s          	Neutral
# so          	Neutral
# delicious   	Positive
# .           	Neutral
# The sentiment of the 0-th sentence is： Positive
# --------------------------------------------------
# This        	Neutral
# chicken     	Neutral
# burger      	Neutral
# has         	Neutral
# a           	Neutral
# very        	Neutral
# bad         	Very negative
# taste       	Neutral
# The sentiment of the 1-th sentence is： Very negative
# --------------------------------------------------

# %% [markdown]
# ### Dependency 視覺化
# + 官網範例: https://corenlp.run/
#
# 剛剛我們已經透過`stanza`套件將coreNLP服務啟動，服務開在`localhost:9008`，我們可以透過`from nltk.parse import CoreNLPParser`將Dependency進行較佳的視覺化。

# %%
parser = CoreNLPParser('http://localhost:9008') # 使用開在loclahost:9008的coreNLP服務
text = 'A blog post using Stanford CoreNLP Server. Visit www.khalidalnajjar.com for more details.'

fox_parsed = next(parser.raw_parse(text))
fox_parsed.pretty_print()
# Out:
#                                           ROOT
#                                            |
#                                            S
#                  __________________________|_____________________________________________________
#                 S                                |                          S                    |
#                 |                                |                          |                    |
#                 NP                               |                          VP                   |
#       __________|_____________                   |     _____________________|___                 |
#      |                        VP                 |    |          |              PP               |
#      |           _____________|_____             |    |          |           ___|____            |
#      NP         |                   NP           |    |          NP         |        NP          |
#   ___|____      |       ____________|______      |    |          |          |    ____|_____      |
#  DT  NN   NN   VBG    NNP           NN     NN    .    VB        ADD         IN JJR        NNS    .
#  |   |    |     |      |            |      |     |    |          |          |   |          |     |
#  A  blog post using Stanford     CoreNLP Server  .  Visit www.khalidalnajj for more     details  .
#                                                                ar.com

# %%
# 最後再把背景的client關掉
client.stop()
time.sleep(5)

# %% [markdown]
# ## 3. CoreNLP 標註
#
# 資料來源:
# + 傲慢與偏見（古騰堡）

# %% [markdown]
# ### 3.1 使用coreNLP進行實作
# 我們已經介紹過coreNLP的使用方式，現在來對前幾週的傲慢與偏見使用coreNLP進行自然語言處理

# %%
## 讀取文章
df = pd.read_csv('./raw_data/eng/en_sentence_chapter.csv')
df_chapter = df.groupby('chapter')['sentence'].apply(lambda x:x.str.cat(sep=' ')).reset_index()

print(f"章節篇數: {df_chapter.shape[0]-1}")
df_chapter.head()
# Out:
# 章節篇數: 61
#    chapter                                           sentence
# 0        0                               ﻿TPRIDE & PREJUDICE.
# 1        1  It is a truth universally acknowledged, that a...
# 2        2  Mr. Bennet was among the earliest of those who...
# 3        3  Not all that Mrs. Bennet, however, with the as...
# 4        4  When Jane and Elizabeth were alone, the former...

# %%
def get_nlp_result(df, text_col, id_col):    
    
    print("Starting a server with the Python \"with\" statement...")
    
    start = time.time()

    with CoreNLPClient(
        annotators = ['tokenize','ssplit', 'pos', 'lemma', 'ner','sentiment','entitymentions'],
        memory = '4G', endpoint = 'http://localhost:9006' , be_quiet=True, 
    ) as client:
        
        token_list = []        
        senti_list = [] 
        mention_list = []
        
        # 注意！！這裡只是示範所以只跑了2筆，要完全執行需要把`.head(2)`移除
        for index, row in df.head(2).iterrows(): # document level  
            # send text into client
            document = client.annotate(row[text_col])                
            print(f"{'Word':12s}\t{'Lemma':12s}\t{'POS':6s}\t{'NER'}")    
            
             # sentence level
            for i, sent in enumerate(document.sentence):                
                s = ""
                # token level
                for t in sent.token: 
                    s = s + " " + t.word # for sentence                
                    print("{:12s}\t{:12s}\t{:6s}\t{}".format(t.word, t.lemma, t.pos, t.ner))                
                    # save lemma, pos, ner
                    temp_token = [row[id_col],t.word, t.lemma, t.pos, t.ner]     
                    token_list.append(temp_token) 
                print("[Sentence {}:{}_____________]".format(i+1, s))                  
                
                # save sentiment, mention
                temp_senti = [row[id_col], s, sent.sentiment]           
                senti_list.append(temp_senti)   
                
                for mention in sent.mentions:
                    print(mention.entityMentionText, mention.ner)
                    temp_mention = [row[id_col], mention.entityMentionText, mention.ner]
                    mention_list.append(temp_mention) 

        token_table = pd.DataFrame(data=token_list, 
                            columns=[id_col,'word','lemma','pos','ner'])        

        senti_table = pd.DataFrame(data=senti_list, 
                            columns=[id_col,'sentence', 'sentiment'])        
        
        mention_table = pd.DataFrame(data=mention_list, 
                            columns=[id_col, 'mention','ner'])        

        end = time.time()

        print("time costing: {}".format(end - start))
        print("\nThe server should be stopped upon exit from the \"with\" statement.")

        return token_table, senti_table , mention_table

# %%
# 找出NER、POS和sentiment分析結果
# 注意！！這裡只是示範所以只跑了2筆
tokens, sentiment, mention  = get_nlp_result(df_chapter,'sentence','chapter') # 資料框, 要處理的文字欄位名, id 欄位名
# time costing: 14.14368200302124
# total time costing: 1227.876435995102
# Out:
# 2023-03-26 14:56:24 INFO: Writing properties to tmp file: corenlp_server-832c889b73104dc8.props
# 2023-03-26 14:56:24 INFO: Starting server with command: java -Xmx4G -cp ./stanza_corenlp/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9006 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-832c889b73104dc8.props -annotators tokenize,ssplit,pos,lemma,ner,sentiment,entitymentions -preload -outputFormat serialized
# Starting a server with the Python "with" statement...
# Word        	Lemma       	POS   	NER
# TPRIDE      	TPRIDE      	NNP   	O
# &           	&           	CC    	O
# PREJUDICE   	PREJUDICE   	NNP   	O
# .           	.           	.     	O
# [Sentence 1: TPRIDE & PREJUDICE ._____________]
# Word        	Lemma       	POS   	NER
# It          	it          	PRP   	O
# is          	be          	VBZ   	O
# a           	a           	DT    	O
# truth       	truth       	NN    	O
# universally 	universally 	RB    	O
# acknowledged	acknowledge 	VBD   	O
# ,           	,           	,     	O
# that        	that        	IN    	O
# a           	a           	DT    	O
# single      	single      	JJ    	O
# man         	man         	NN    	O
# in          	in          	IN    	O
# possession  	possession  	NN    	O
# of          	of          	IN    	O
# a           	a           	DT    	O
# good        	good        	JJ    	O
# fortune     	fortune     	NN    	O
# ,           	,           	,     	O
# must        	must        	MD    	O
# be          	be          	VB    	O
# in          	in          	IN    	O
# want        	want        	NN    	O
# of          	of          	IN    	O
# a           	a           	DT    	O
# wife        	wife        	NN    	O
# .           	.           	.     	O
# [Sentence 1: It is a truth universally acknowledged , that a single man in possession of a good fortune , must be in want of a wife ._____________]
# However     	however     	RB    	O
# little      	little      	RB    	O
# known       	know        	VBN   	O
# the         	the         	DT    	O
# feelings    	feeling     	NNS   	O
# or          	or          	CC    	O
# views       	view        	NNS   	O
# of          	of          	IN    	O
# such        	such        	PDT   	O
# a           	a           	DT    	O
# man         	man         	NN    	O
# may         	may         	MD    	O
# be          	be          	VB    	O
# on          	on          	IN    	O
# his         	he          	PRP$  	O
# first       	first       	JJ    	ORDINAL
# entering    	enter       	VBG   	O
# a           	a           	DT    	O
# neighbourhood	neighbourhood	NN    	O
# ,           	,           	,     	O
# this        	this        	DT    	O
# truth       	truth       	NN    	O
# is          	be          	VBZ   	O
# so          	so          	RB    	O
# well        	well        	RB    	O
# fixed       	fix         	VBN   	O
# in          	in          	IN    	O
# the         	the         	DT    	O
# minds       	mind        	NNS   	O
# of          	of          	IN    	O
# the         	the         	DT    	O
# surrounding 	surround    	VBG   	O
# families    	family      	NNS   	O
# ,           	,           	,     	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# is          	be          	VBZ   	O
# considered  	consider    	VBN   	O
# as          	as          	IN    	O
# the         	the         	DT    	O
# rightful    	rightful    	JJ    	O
# property    	property    	NN    	O
# of          	of          	IN    	O
# some        	some        	DT    	O
# one         	one         	CD    	NUMBER
# or          	or          	CC    	O
# other       	other       	JJ    	O
# of          	of          	IN    	O
# their       	they        	PRP$  	O
# daughters   	daughter    	NNS   	O
# .           	.           	.     	O
# [Sentence 2: However little known the feelings or views of such a man may be on his first entering a neighbourhood , this truth is so well fixed in the minds of the surrounding families , that he is considered as the rightful property of some one or other of their daughters ._____________]
# first ORDINAL
# one NUMBER
# his PERSON
# he PERSON
# "           	"           	``    	O
# My          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# ,           	,           	,     	O
# "           	"           	''    	O
# said        	say         	VBD   	O
# his         	he          	PRP$  	O
# lady        	lady        	NN    	O
# to          	to          	IN    	O
# him         	he          	PRP   	O
# one         	one         	CD    	DURATION
# day         	day         	NN    	DURATION
# ,           	,           	,     	O
# "           	"           	''    	O
# have        	have        	VBP   	O
# you         	you         	PRP   	O
# heard       	hear        	VBN   	O
# that        	that        	IN    	O
# Netherfield 	Netherfield 	NNP   	LOCATION
# Park        	Park        	NNP   	LOCATION
# is          	be          	VBZ   	O
# let         	let         	VBN   	O
# at          	at          	IN    	O
# last        	last        	JJ    	O
# ?           	?           	.     	O
# "           	"           	''    	O
# [Sentence 3: " My dear Mr. Bennet , " said his lady to him one day , " have you heard that Netherfield Park is let at last ? "_____________]
# Bennet PERSON
# one day DURATION
# Netherfield Park LOCATION
# his PERSON
# him PERSON
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# replied     	reply       	VBD   	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# had         	have        	VBD   	O
# not         	not         	RB    	O
# .           	.           	.     	O
# [Sentence 4: Mr. Bennet replied that he had not ._____________]
# Bennet PERSON
# he PERSON
# "           	"           	``    	O
# But         	but         	CC    	O
# it          	it          	PRP   	O
# is          	be          	VBZ   	O
# ,           	,           	,     	O
# "           	"           	``    	O
# returned    	return      	VBD   	O
# she         	she         	PRP   	O
# ;           	;           	:     	O
# "           	"           	''    	O
# for         	for         	IN    	O
# Mrs.        	Mrs.        	NNP   	O
# Long        	Long        	NNP   	PERSON
# has         	have        	VBZ   	O
# just        	just        	RB    	O
# been        	be          	VBN   	O
# here        	here        	RB    	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# she         	she         	PRP   	O
# told        	tell        	VBD   	O
# me          	I           	PRP   	O
# all         	all         	DT    	O
# about       	about       	IN    	O
# it          	it          	PRP   	O
# .           	.           	.     	O
# "           	"           	''    	O
# [Sentence 5: " But it is , " returned she ; " for Mrs. Long has just been here , and she told me all about it . "_____________]
# Long PERSON
# she PERSON
# she PERSON
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# made        	make        	VBD   	O
# no          	no          	DT    	O
# answer      	answer      	NN    	O
# .           	.           	.     	O
# [Sentence 6: Mr. Bennet made no answer ._____________]
# Bennet PERSON
# "           	"           	``    	O
# Do          	do          	VB    	O
# not         	not         	RB    	O
# you         	you         	PRP   	O
# want        	want        	VBP   	O
# to          	to          	TO    	O
# know        	know        	VB    	O
# who         	who         	WP    	O
# has         	have        	VBZ   	O
# taken       	take        	VBN   	O
# it          	it          	PRP   	O
# ?           	?           	.     	O
# "           	"           	''    	O
# [Sentence 7: " Do not you want to know who has taken it ? "_____________]
# cried       	cry         	VBD   	O
# his         	he          	PRP$  	O
# wife        	wife        	NN    	O
# impatiently 	impatiently 	RB    	O
# .           	.           	.     	O
# [Sentence 8: cried his wife impatiently ._____________]
# his PERSON
# "           	"           	``    	O
# _           	_           	NFP   	O
# You         	you         	PRP   	O
# _           	_           	NFP   	O
# want        	want        	VBP   	O
# to          	to          	TO    	O
# tell        	tell        	VB    	O
# me          	I           	PRP   	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# I           	I           	PRP   	O
# have        	have        	VBP   	O
# no          	no          	DT    	O
# objection   	objection   	NN    	O
# to          	to          	IN    	O
# hearing     	hear        	VBG   	O
# it          	it          	PRP   	O
# .           	.           	.     	O
# "           	"           	''    	O
# [Sentence 9: " _ You _ want to tell me , and I have no objection to hearing it . "_____________]
# This        	this        	DT    	O
# was         	be          	VBD   	O
# invitation  	invitation  	NN    	O
# enough      	enough      	RB    	O
# .           	.           	.     	O
# [Sentence 10: This was invitation enough ._____________]
# "           	"           	``    	O
# Why         	why         	WRB   	O
# ,           	,           	,     	O
# my          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# ,           	,           	,     	O
# you         	you         	PRP   	O
# must        	must        	MD    	O
# know        	know        	VB    	O
# ,           	,           	,     	O
# Mrs.        	Mrs.        	NNP   	O
# Long        	Long        	NNP   	PERSON
# says        	say         	VBZ   	O
# that        	that        	IN    	O
# Netherfield 	Netherfield 	NNP   	LOCATION
# is          	be          	VBZ   	O
# taken       	take        	VBN   	O
# by          	by          	IN    	O
# a           	a           	DT    	O
# young       	young       	JJ    	O
# man         	man         	NN    	O
# of          	of          	IN    	O
# large       	large       	JJ    	O
# fortune     	fortune     	NN    	O
# from        	from        	IN    	O
# the         	the         	DT    	O
# north       	north       	NN    	O
# of          	of          	IN    	O
# England     	England     	NNP   	COUNTRY
# ;           	;           	:     	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# came        	come        	VBD   	O
# down        	down        	RP    	O
# on          	on          	IN    	O
# Monday      	Monday      	NNP   	DATE
# in          	in          	IN    	O
# a           	a           	DT    	O
# chaise      	chaise      	NN    	O
# and         	and         	CC    	O
# four        	four        	CD    	NUMBER
# to          	to          	TO    	O
# see         	see         	VB    	O
# the         	the         	DT    	O
# place       	place       	NN    	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# was         	be          	VBD   	O
# so          	so          	RB    	O
# much        	much        	JJ    	O
# delighted   	delighted   	JJ    	O
# with        	with        	IN    	O
# it          	it          	PRP   	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# agreed      	agree       	VBD   	O
# with        	with        	IN    	O
# Mr.         	Mr.         	NNP   	O
# Morris      	Morris      	NNP   	PERSON
# immediately 	immediately 	RB    	O
# ;           	;           	:     	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# is          	be          	VBZ   	O
# to          	to          	TO    	O
# take        	take        	VB    	O
# possession  	possession  	NN    	O
# before      	before      	IN    	O
# Michaelmas  	Michaelmas  	NNP   	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# some        	some        	DT    	O
# of          	of          	IN    	O
# his         	he          	PRP$  	O
# servants    	servant     	NNS   	O
# are         	be          	VBP   	O
# to          	to          	TO    	O
# be          	be          	VB    	O
# in          	in          	IN    	O
# the         	the         	DT    	O
# house       	house       	NN    	O
# by          	by          	IN    	O
# the         	the         	DT    	DATE
# end         	end         	NN    	DATE
# of          	of          	IN    	DATE
# next        	next        	JJ    	DATE
# week        	week        	NN    	DATE
# .           	.           	.     	O
# "           	"           	''    	O
# [Sentence 11: " Why , my dear , you must know , Mrs. Long says that Netherfield is taken by a young man of large fortune from the north of England ; that he came down on Monday in a chaise and four to see the place , and was so much delighted with it that he agreed with Mr. Morris immediately ; that he is to take possession before Michaelmas , and some of his servants are to be in the house by the end of next week . "_____________]
# Long PERSON
# Netherfield LOCATION
# England COUNTRY
# Monday DATE
# four NUMBER
# Morris PERSON
# the end of next week DATE
# he PERSON
# he PERSON
# he PERSON
# his PERSON
# "           	"           	``    	O
# What        	what        	WP    	O
# is          	be          	VBZ   	O
# his         	he          	PRP$  	O
# name        	name        	NN    	O
# ?           	?           	.     	O
# "           	"           	''    	O
# [Sentence 12: " What is his name ? "_____________]
# his PERSON
# "           	"           	``    	O
# Bingley     	Bingley     	NNP   	O
# .           	.           	.     	O
# "           	"           	''    	O
# [Sentence 13: " Bingley . "_____________]
# "           	"           	``    	O
# Is          	be          	VBZ   	O
# he          	he          	PRP   	O
# married     	marry       	VBD   	O
# or          	or          	CC    	O
# single      	single      	JJ    	O
# ?           	?           	.     	O
# "           	"           	''    	O
# [Sentence 14: " Is he married or single ? "_____________]
# he PERSON
# "           	"           	``    	O
# Oh          	oh          	UH    	O
# !           	!           	.     	O
# [Sentence 15: " Oh !_____________]
# single      	single      	JJ    	O
# ,           	,           	,     	O
# my          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# ,           	,           	,     	O
# to          	to          	TO    	O
# be          	be          	VB    	O
# sure        	sure        	JJ    	O
# !           	!           	.     	O
# [Sentence 16: single , my dear , to be sure !_____________]
# A           	a           	DT    	O
# single      	single      	JJ    	O
# man         	man         	NN    	O
# of          	of          	IN    	O
# large       	large       	JJ    	O
# fortune     	fortune     	NN    	O
# ;           	;           	,     	O
# four        	four        	CD    	NUMBER
# or          	or          	CC    	O
# five        	five        	CD    	NUMBER
# thousand    	thousand    	CD    	NUMBER
# a           	a           	DT    	DURATION
# year        	year        	NN    	DURATION
# .           	.           	.     	O
# [Sentence 17: A single man of large fortune ; four or five thousand a year ._____________]
# four NUMBER
# five thousand NUMBER
# a year DURATION
# What        	what        	WDT   	O
# a           	a           	DT    	O
# fine        	fine        	JJ    	O
# thing       	thing       	NN    	O
# for         	for         	IN    	O
# our         	we          	PRP$  	O
# girls       	girl        	NNS   	O
# !           	!           	.     	O
# [Sentence 18: What a fine thing for our girls !_____________]
# "           	"           	``    	O
# "           	"           	``    	O
# How         	how         	WRB   	O
# so          	so          	RB    	O
# ?           	?           	.     	O
# [Sentence 19: " " How so ?_____________]
# how         	how         	WRB   	O
# can         	can         	MD    	O
# it          	it          	PRP   	O
# affect      	affect      	VB    	O
# them        	they        	PRP   	O
# ?           	?           	.     	O
# [Sentence 20: how can it affect them ?_____________]
# "           	"           	``    	O
# "           	"           	``    	O
# My          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# ,           	,           	,     	O
# "           	"           	``    	O
# replied     	reply       	VBD   	O
# his         	he          	PRP$  	O
# wife        	wife        	NN    	O
# ,           	,           	,     	O
# "           	"           	''    	O
# how         	how         	WRB   	O
# can         	can         	MD    	O
# you         	you         	PRP   	O
# be          	be          	VB    	O
# so          	so          	RB    	O
# tiresome    	tiresome    	JJ    	O
# !           	!           	.     	O
# [Sentence 21: " " My dear Mr. Bennet , " replied his wife , " how can you be so tiresome !_____________]
# Bennet PERSON
# his PERSON
# You         	you         	PRP   	O
# must        	must        	MD    	O
# know        	know        	VB    	O
# that        	that        	IN    	O
# I           	I           	PRP   	O
# am          	be          	VBP   	O
# thinking    	think       	VBG   	O
# of          	of          	IN    	O
# his         	he          	PRP$  	O
# marrying    	marry       	VBG   	O
# one         	one         	CD    	NUMBER
# of          	of          	IN    	O
# them        	they        	PRP   	O
# .           	.           	.     	O
# [Sentence 22: You must know that I am thinking of his marrying one of them ._____________]
# one NUMBER
# his PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# Is          	be          	VBZ   	O
# that        	that        	DT    	O
# his         	he          	PRP$  	O
# design      	design      	NN    	O
# in          	in          	IN    	O
# settling    	settle      	VBG   	O
# here        	here        	RB    	O
# ?           	?           	.     	O
# [Sentence 23: " " Is that his design in settling here ?_____________]
# his PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# Design      	design      	NN    	O
# !           	!           	.     	O
# [Sentence 24: " " Design !_____________]
# nonsense    	nonsense    	NN    	O
# ,           	,           	,     	O
# how         	how         	WRB   	O
# can         	can         	MD    	O
# you         	you         	PRP   	O
# talk        	talk        	VB    	O
# so          	so          	RB    	O
# !           	!           	.     	O
# [Sentence 25: nonsense , how can you talk so !_____________]
# But         	but         	CC    	O
# it          	it          	PRP   	O
# is          	be          	VBZ   	O
# very        	very        	RB    	O
# likely      	likely      	JJ    	O
# that        	that        	IN    	O
# he          	he          	PRP   	O
# _           	_           	NFP   	O
# may         	may         	MD    	O
# _           	_           	NFP   	O
# fall        	fall        	VB    	O
# in          	in          	IN    	O
# love        	love        	NN    	O
# with        	with        	IN    	O
# one         	one         	CD    	NUMBER
# of          	of          	IN    	O
# them        	they        	PRP   	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# therefore   	therefore   	RB    	O
# you         	you         	PRP   	O
# must        	must        	MD    	O
# visit       	visit       	VB    	O
# him         	he          	PRP   	O
# as          	as          	RB    	O
# soon        	soon        	RB    	O
# as          	as          	IN    	O
# he          	he          	PRP   	O
# comes       	come        	VBZ   	O
# .           	.           	.     	O
# [Sentence 26: But it is very likely that he _ may _ fall in love with one of them , and therefore you must visit him as soon as he comes ._____________]
# one NUMBER
# he PERSON
# him PERSON
# he PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# I           	I           	PRP   	O
# see         	see         	VBP   	O
# no          	no          	DT    	O
# occasion    	occasion    	NN    	O
# for         	for         	IN    	O
# that        	that        	DT    	O
# .           	.           	.     	O
# [Sentence 27: " " I see no occasion for that ._____________]
# You         	you         	PRP   	O
# and         	and         	CC    	O
# the         	the         	DT    	O
# girls       	girl        	NNS   	O
# may         	may         	MD    	O
# go          	go          	VB    	O
# ,           	,           	,     	O
# or          	or          	CC    	O
# you         	you         	PRP   	O
# may         	may         	MD    	O
# send        	send        	VB    	O
# them        	they        	PRP   	O
# by          	by          	IN    	O
# themselves  	themselves  	PRP   	O
# ,           	,           	,     	O
# which       	which       	WDT   	O
# perhaps     	perhaps     	RB    	O
# will        	will        	MD    	O
# be          	be          	VB    	O
# still       	still       	RB    	O
# better      	good        	JJR   	O
# ,           	,           	,     	O
# for         	for         	IN    	O
# as          	as          	IN    	O
# you         	you         	PRP   	O
# are         	be          	VBP   	O
# as          	as          	IN    	O
# handsome    	handsome    	JJ    	O
# as          	as          	IN    	O
# any         	any         	DT    	O
# of          	of          	IN    	O
# them        	they        	PRP   	O
# ,           	,           	,     	O
# Mr.         	Mr.         	NNP   	O
# Bingley     	Bingley     	NNP   	PERSON
# might       	might       	MD    	O
# like        	like        	VB    	O
# you         	you         	PRP   	O
# the         	the         	DT    	O
# best        	good        	JJS   	O
# of          	of          	IN    	O
# the         	the         	DT    	O
# party       	party       	NN    	O
# .           	.           	.     	O
# [Sentence 28: You and the girls may go , or you may send them by themselves , which perhaps will be still better , for as you are as handsome as any of them , Mr. Bingley might like you the best of the party ._____________]
# Bingley PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# My          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# ,           	,           	,     	O
# you         	you         	PRP   	O
# flatter     	flat        	JJR   	O
# me          	I           	PRP   	O
# .           	.           	.     	O
# [Sentence 29: " " My dear , you flatter me ._____________]
# I           	I           	PRP   	O
# certainly   	certainly   	RB    	O
# _           	_           	NFP   	O
# have        	have        	VBP   	O
# _           	_           	NFP   	O
# had         	have        	VBD   	O
# my          	my          	PRP$  	O
# share       	share       	NN    	O
# of          	of          	IN    	O
# beauty      	beauty      	NN    	O
# ,           	,           	,     	O
# but         	but         	CC    	O
# I           	I           	PRP   	O
# do          	do          	VBP   	O
# not         	not         	RB    	O
# pretend     	pretend     	VB    	O
# to          	to          	TO    	O
# be          	be          	VB    	O
# any         	any         	DT    	O
# thing       	thing       	NN    	O
# extraordinary	extraordinary	JJ    	O
# now         	now         	RB    	DATE
# .           	.           	.     	O
# [Sentence 30: I certainly _ have _ had my share of beauty , but I do not pretend to be any thing extraordinary now ._____________]
# now DATE
# When        	when        	WRB   	O
# a           	a           	DT    	O
# woman       	woman       	NN    	O
# has         	have        	VBZ   	O
# five        	five        	CD    	NUMBER
# grown       	grow        	VBN   	O
# up          	up          	RP    	O
# daughters   	daughter    	NNS   	O
# ,           	,           	,     	O
# she         	she         	PRP   	O
# ought       	ought       	MD    	O
# to          	to          	TO    	O
# give        	give        	VB    	O
# over        	over        	RP    	O
# thinking    	thinking    	NN    	O
# of          	of          	IN    	O
# her         	she         	PRP$  	O
# own         	own         	JJ    	O
# beauty      	beauty      	NN    	O
# .           	.           	.     	O
# [Sentence 31: When a woman has five grown up daughters , she ought to give over thinking of her own beauty ._____________]
# five NUMBER
# she PERSON
# her PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# In          	in          	IN    	O
# such        	such        	JJ    	O
# cases       	case        	NNS   	O
# ,           	,           	,     	O
# a           	a           	DT    	O
# woman       	woman       	NN    	O
# has         	have        	VBZ   	O
# not         	not         	RB    	O
# often       	often       	RB    	O
# much        	much        	JJ    	O
# beauty      	beauty      	NN    	O
# to          	to          	TO    	O
# think       	think       	VB    	O
# of          	of          	IN    	O
# .           	.           	.     	O
# [Sentence 32: " " In such cases , a woman has not often much beauty to think of ._____________]
# "           	"           	``    	O
# "           	"           	``    	O
# But         	but         	CC    	O
# ,           	,           	,     	O
# my          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# ,           	,           	,     	O
# you         	you         	PRP   	O
# must        	must        	MD    	O
# indeed      	indeed      	RB    	O
# go          	go          	VB    	O
# and         	and         	CC    	O
# see         	see         	VB    	O
# Mr.         	Mr.         	NNP   	O
# Bingley     	Bingley     	NNP   	PERSON
# when        	when        	WRB   	O
# he          	he          	PRP   	O
# comes       	come        	VBZ   	O
# into        	into        	IN    	O
# the         	the         	DT    	O
# neighbourhood	neighbourhood	NN    	O
# .           	.           	.     	O
# [Sentence 33: " " But , my dear , you must indeed go and see Mr. Bingley when he comes into the neighbourhood ._____________]
# Bingley PERSON
# he PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# It          	it          	PRP   	O
# is          	be          	VBZ   	O
# more        	more        	JJR   	O
# than        	than        	IN    	O
# I           	I           	PRP   	O
# engage      	engage      	VBP   	O
# for         	for         	IN    	O
# ,           	,           	,     	O
# I           	I           	PRP   	O
# assure      	assure      	VBP   	O
# you         	you         	PRP   	O
# .           	.           	.     	O
# [Sentence 34: " " It is more than I engage for , I assure you ._____________]
# "           	"           	``    	O
# "           	"           	``    	O
# But         	but         	CC    	O
# consider    	consider    	VB    	O
# your        	you         	PRP$  	O
# daughters   	daughter    	NNS   	O
# .           	.           	.     	O
# [Sentence 35: " " But consider your daughters ._____________]
# Only        	only        	RB    	O
# think       	think       	VB    	O
# what        	what        	WP    	O
# an          	a           	DT    	O
# establishment	establishment	NN    	O
# it          	it          	PRP   	O
# would       	would       	MD    	O
# be          	be          	VB    	O
# for         	for         	IN    	O
# one         	one         	CD    	NUMBER
# of          	of          	IN    	O
# them        	they        	PRP   	O
# .           	.           	.     	O
# [Sentence 36: Only think what an establishment it would be for one of them ._____________]
# one NUMBER
# Sir         	Sir         	NNP   	O
# William     	William     	NNP   	PERSON
# and         	and         	CC    	O
# Lady        	Lady        	NNP   	PERSON
# Lucas       	Lucas       	NNP   	PERSON
# are         	be          	VBP   	O
# determined  	determine   	VBN   	O
# to          	to          	TO    	O
# go          	go          	VB    	O
# ,           	,           	,     	O
# merely      	merely      	RB    	O
# on          	on          	IN    	O
# that        	that        	DT    	O
# account     	account     	NN    	O
# ,           	,           	,     	O
# for         	for         	IN    	O
# in          	in          	IN    	O
# general     	general     	JJ    	TITLE
# you         	you         	PRP   	O
# know        	know        	VBP   	O
# they        	they        	PRP   	O
# visit       	visit       	VB    	O
# no          	no          	DT    	O
# new         	new         	JJ    	O
# comers      	comer       	NNS   	O
# .           	.           	.     	O
# [Sentence 37: Sir William and Lady Lucas are determined to go , merely on that account , for in general you know they visit no new comers ._____________]
# William PERSON
# Lady Lucas PERSON
# general TITLE
# Indeed      	indeed      	RB    	O
# you         	you         	PRP   	O
# must        	must        	MD    	O
# go          	go          	VB    	O
# ,           	,           	,     	O
# for         	for         	IN    	O
# it          	it          	PRP   	O
# will        	will        	MD    	O
# be          	be          	VB    	O
# impossible  	impossible  	JJ    	O
# for         	for         	IN    	O
# _           	_           	NFP   	O
# us          	we          	PRP   	O
# _           	_           	NFP   	O
# to          	to          	TO    	O
# visit       	visit       	VB    	O
# him         	he          	PRP   	O
# ,           	,           	,     	O
# if          	if          	IN    	O
# you         	you         	PRP   	O
# do          	do          	VBP   	O
# not         	not         	RB    	O
# .           	.           	.     	O
# [Sentence 38: Indeed you must go , for it will be impossible for _ us _ to visit him , if you do not ._____________]
# him PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# You         	you         	PRP   	O
# are         	be          	VBP   	O
# over        	over        	IN    	O
# scrupulous  	scrupulous  	JJ    	O
# surely      	surely      	RB    	O
# .           	.           	.     	O
# [Sentence 39: " " You are over scrupulous surely ._____________]
# I           	I           	PRP   	O
# dare        	dare        	MD    	O
# say         	say         	VB    	O
# Mr.         	Mr.         	NNP   	O
# Bingley     	Bingley     	NNP   	PERSON
# will        	will        	MD    	O
# be          	be          	VB    	O
# very        	very        	RB    	O
# glad        	glad        	JJ    	O
# to          	to          	TO    	O
# see         	see         	VB    	O
# you         	you         	PRP   	O
# ;           	;           	:     	O
# and         	and         	CC    	O
# I           	I           	PRP   	O
# will        	will        	MD    	O
# send        	send        	VB    	O
# a           	a           	DT    	O
# few         	few         	JJ    	O
# lines       	line        	NNS   	O
# by          	by          	IN    	O
# you         	you         	PRP   	O
# to          	to          	TO    	O
# assure      	assure      	VB    	O
# him         	he          	PRP   	O
# of          	of          	IN    	O
# my          	my          	PRP$  	O
# hearty      	hearty      	JJ    	O
# consent     	consent     	NN    	O
# to          	to          	IN    	O
# his         	he          	PRP$  	O
# marrying    	marrying    	NN    	O
# which       	which       	WDT   	O
# ever        	ever        	RB    	O
# he          	he          	PRP   	O
# chuses      	chus        	VBZ   	O
# of          	of          	IN    	O
# the         	the         	DT    	O
# girls       	girl        	NNS   	O
# ;           	;           	:     	O
# though      	though      	IN    	O
# I           	I           	PRP   	O
# must        	must        	MD    	O
# throw       	throw       	VB    	O
# in          	in          	RP    	O
# a           	a           	DT    	O
# good        	good        	JJ    	O
# word        	word        	NN    	O
# for         	for         	IN    	O
# my          	my          	PRP$  	O
# little      	little      	JJ    	O
# Lizzy       	Lizzy       	NNP   	PERSON
# .           	.           	.     	O
# [Sentence 40: I dare say Mr. Bingley will be very glad to see you ; and I will send a few lines by you to assure him of my hearty consent to his marrying which ever he chuses of the girls ; though I must throw in a good word for my little Lizzy ._____________]
# Bingley PERSON
# Lizzy PERSON
# him PERSON
# his PERSON
# he PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# I           	I           	PRP   	O
# desire      	desire      	VBP   	O
# you         	you         	PRP   	O
# will        	will        	MD    	O
# do          	do          	VB    	O
# no          	no          	DT    	O
# such        	such        	JJ    	O
# thing       	thing       	NN    	O
# .           	.           	.     	O
# [Sentence 41: " " I desire you will do no such thing ._____________]
# Lizzy       	Lizzy       	NNP   	PERSON
# is          	be          	VBZ   	O
# not         	not         	RB    	O
# a           	a           	DT    	O
# bit         	bit         	NN    	O
# better      	good        	JJR   	O
# than        	than        	IN    	O
# the         	the         	DT    	O
# others      	other       	NNS   	O
# ;           	;           	:     	O
# and         	and         	CC    	O
# I           	I           	PRP   	O
# am          	be          	VBP   	O
# sure        	sure        	JJ    	O
# she         	she         	PRP   	O
# is          	be          	VBZ   	O
# not         	not         	RB    	O
# half        	half        	JJ    	O
# so          	so          	RB    	O
# handsome    	handsome    	JJ    	O
# as          	as          	IN    	O
# Jane        	Jane        	NNP   	PERSON
# ,           	,           	,     	O
# nor         	nor         	CC    	O
# half        	half        	NN    	O
# so          	so          	RB    	O
# good        	good        	JJ    	O
# humoured    	humour      	VBN   	O
# as          	as          	IN    	O
# Lydia       	Lydia       	NNP   	PERSON
# .           	.           	.     	O
# [Sentence 42: Lizzy is not a bit better than the others ; and I am sure she is not half so handsome as Jane , nor half so good humoured as Lydia ._____________]
# Lizzy PERSON
# Jane PERSON
# Lydia PERSON
# she PERSON
# But         	but         	CC    	O
# you         	you         	PRP   	O
# are         	be          	VBP   	O
# always      	always      	RB    	O
# giving      	give        	VBG   	O
# _           	_           	NFP   	O
# her         	she         	PRP$  	O
# _           	_           	NFP   	O
# the         	the         	DT    	O
# preference  	preference  	NN    	O
# .           	.           	.     	O
# [Sentence 43: But you are always giving _ her _ the preference ._____________]
# her PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# They        	they        	PRP   	O
# have        	have        	VBP   	O
# none        	none        	NN    	O
# of          	of          	IN    	O
# them        	they        	PRP   	O
# much        	much        	RB    	O
# to          	to          	TO    	O
# recommend   	recommend   	VB    	O
# them        	they        	PRP   	O
# ,           	,           	,     	O
# "           	"           	``    	O
# replied     	reply       	VBD   	O
# he          	he          	PRP   	O
# ;           	;           	:     	O
# "           	"           	``    	O
# they        	they        	PRP   	O
# are         	be          	VBP   	O
# all         	all         	RB    	O
# silly       	silly       	JJ    	O
# and         	and         	CC    	O
# ignorant    	ignorant    	JJ    	O
# like        	like        	IN    	O
# other       	other       	JJ    	O
# girls       	girl        	NNS   	O
# ;           	;           	:     	O
# but         	but         	CC    	O
# Lizzy       	Lizzy       	NNP   	PERSON
# has         	have        	VBZ   	O
# something   	something   	NN    	O
# more        	more        	JJR   	O
# of          	of          	IN    	O
# quickness   	quickness   	NN    	O
# than        	than        	IN    	O
# her         	she         	PRP$  	O
# sisters     	sister      	NNS   	O
# .           	.           	.     	O
# [Sentence 44: " " They have none of them much to recommend them , " replied he ; " they are all silly and ignorant like other girls ; but Lizzy has something more of quickness than her sisters ._____________]
# Lizzy PERSON
# he PERSON
# her PERSON
# "           	"           	``    	O
# "           	"           	``    	O
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# ,           	,           	,     	O
# how         	how         	WRB   	O
# can         	can         	MD    	O
# you         	you         	PRP   	O
# abuse       	abuse       	VB    	O
# your        	you         	PRP$  	O
# own         	own         	JJ    	O
# children    	child       	NNS   	O
# in          	in          	IN    	O
# such        	such        	PDT   	O
# a           	a           	DT    	O
# way         	way         	NN    	O
# ?           	?           	.     	O
# [Sentence 45: " " Mr. Bennet , how can you abuse your own children in such a way ?_____________]
# Bennet PERSON
# You         	you         	PRP   	O
# take        	take        	VBP   	O
# delight     	delight     	NN    	O
# in          	in          	IN    	O
# vexing      	vexing      	JJ    	O
# me          	I           	PRP   	O
# .           	.           	.     	O
# [Sentence 46: You take delight in vexing me ._____________]
# You         	you         	PRP   	O
# have        	have        	VBP   	O
# no          	no          	DT    	O
# compassion  	compassion  	NN    	O
# on          	on          	IN    	O
# my          	my          	PRP$  	O
# poor        	poor        	JJ    	O
# nerves      	nerve       	NNS   	O
# .           	.           	.     	O
# [Sentence 47: You have no compassion on my poor nerves ._____________]
# "           	"           	``    	O
# "           	"           	``    	O
# You         	you         	PRP   	O
# mistake     	mistake     	VBP   	O
# me          	I           	PRP   	O
# ,           	,           	,     	O
# my          	my          	PRP$  	O
# dear        	dear        	NN    	O
# .           	.           	.     	O
# [Sentence 48: " " You mistake me , my dear ._____________]
# I           	I           	PRP   	O
# have        	have        	VBP   	O
# a           	a           	DT    	O
# high        	high        	JJ    	O
# respect     	respect     	NN    	O
# for         	for         	IN    	O
# your        	you         	PRP$  	O
# nerves      	nerve       	NNS   	O
# .           	.           	.     	O
# [Sentence 49: I have a high respect for your nerves ._____________]
# They        	they        	PRP   	O
# are         	be          	VBP   	O
# my          	my          	PRP$  	O
# old         	old         	JJ    	O
# friends     	friend      	NNS   	O
# .           	.           	.     	O
# [Sentence 50: They are my old friends ._____________]
# I           	I           	PRP   	O
# have        	have        	VBP   	O
# heard       	hear        	VBN   	O
# you         	you         	PRP   	O
# mention     	mention     	VBP   	O
# them        	they        	PRP   	O
# with        	with        	IN    	O
# consideration	consideration	NN    	O
# these       	this        	DT    	O
# twenty      	twenty      	CD    	DURATION
# years       	year        	NNS   	DURATION
# at          	at          	IN    	O
# least       	least       	RBS   	O
# .           	.           	.     	O
# [Sentence 51: I have heard you mention them with consideration these twenty years at least ._____________]
# twenty years DURATION
# "           	"           	``    	O
# "           	"           	``    	O
# Ah          	ah          	UH    	O
# !           	!           	.     	O
# [Sentence 52: " " Ah !_____________]
# you         	you         	PRP   	O
# do          	do          	VBP   	O
# not         	not         	RB    	O
# know        	know        	VB    	O
# what        	what        	WP    	O
# I           	I           	PRP   	O
# suffer      	suffer      	VBP   	O
# .           	.           	.     	O
# [Sentence 53: you do not know what I suffer ._____________]
# "           	"           	``    	O
# "           	"           	``    	O
# But         	but         	CC    	O
# I           	I           	PRP   	O
# hope        	hope        	VBP   	O
# you         	you         	PRP   	O
# will        	will        	MD    	O
# get         	get         	VB    	O
# over        	over        	IN    	O
# it          	it          	PRP   	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# live        	live        	VB    	O
# to          	to          	TO    	O
# see         	see         	VB    	O
# many        	many        	JJ    	O
# young       	young       	JJ    	O
# men         	man         	NNS   	O
# of          	of          	IN    	O
# four        	four        	CD    	NUMBER
# thousand    	thousand    	CD    	NUMBER
# a           	a           	DT    	DURATION
# year        	year        	NN    	DURATION
# come        	come        	VB    	O
# into        	into        	IN    	O
# the         	the         	DT    	O
# neighbourhood	neighbourhood	NN    	O
# .           	.           	.     	O
# [Sentence 54: " " But I hope you will get over it , and live to see many young men of four thousand a year come into the neighbourhood ._____________]
# four thousand NUMBER
# a year DURATION
# "           	"           	``    	O
# "           	"           	``    	O
# It          	it          	PRP   	O
# will        	will        	MD    	O
# be          	be          	VB    	O
# no          	no          	DT    	O
# use         	use         	NN    	O
# to          	to          	IN    	O
# us          	we          	PRP   	O
# ,           	,           	,     	O
# if          	if          	IN    	O
# twenty      	twenty      	CD    	NUMBER
# such        	such        	JJ    	O
# should      	should      	MD    	O
# come        	come        	VB    	O
# since       	since       	IN    	O
# you         	you         	PRP   	O
# will        	will        	MD    	O
# not         	not         	RB    	O
# visit       	visit       	VB    	O
# them        	they        	PRP   	O
# .           	.           	.     	O
# [Sentence 55: " " It will be no use to us , if twenty such should come since you will not visit them ._____________]
# twenty NUMBER
# "           	"           	``    	O
# "           	"           	``    	O
# Depend      	depend      	VB    	O
# upon        	upon        	IN    	O
# it          	it          	PRP   	O
# ,           	,           	,     	O
# my          	my          	PRP$  	O
# dear        	dear        	JJ    	O
# ,           	,           	,     	O
# that        	that        	IN    	O
# when        	when        	WRB   	O
# there       	there       	EX    	O
# are         	be          	VBP   	O
# twenty      	twenty      	CD    	NUMBER
# ,           	,           	,     	O
# I           	I           	PRP   	O
# will        	will        	MD    	O
# visit       	visit       	VB    	O
# them        	they        	PRP   	O
# all         	all         	DT    	O
# .           	.           	.     	O
# [Sentence 56: " " Depend upon it , my dear , that when there are twenty , I will visit them all ._____________]
# twenty NUMBER
# "           	"           	``    	O
# Mr.         	Mr.         	NNP   	O
# Bennet      	Bennet      	NNP   	PERSON
# was         	be          	VBD   	O
# so          	so          	RB    	O
# odd         	odd         	JJ    	O
# a           	a           	DT    	O
# mixture     	mixture     	NN    	O
# of          	of          	IN    	O
# quick       	quick       	JJ    	O
# parts       	part        	NNS   	O
# ,           	,           	,     	O
# sarcastic   	sarcastic   	JJ    	O
# humour      	humour      	NN    	O
# ,           	,           	,     	O
# reserve     	reserve     	NN    	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# caprice     	caprice     	NN    	O
# ,           	,           	,     	O
# that        	that        	IN    	O
# the         	the         	DT    	O
# experience  	experience  	NN    	O
# of          	of          	IN    	O
# three       	three       	CD    	NUMBER
# and         	and         	CC    	O
# twenty      	twenty      	CD    	DURATION
# years       	year        	NNS   	DURATION
# had         	have        	VBD   	O
# been        	be          	VBN   	O
# insufficient	insufficient	JJ    	O
# to          	to          	TO    	O
# make        	make        	VB    	O
# his         	he          	PRP$  	O
# wife        	wife        	NN    	O
# understand  	understand  	VB    	O
# his         	he          	PRP$  	O
# character   	character   	NN    	O
# .           	.           	.     	O
# [Sentence 57: " Mr. Bennet was so odd a mixture of quick parts , sarcastic humour , reserve , and caprice , that the experience of three and twenty years had been insufficient to make his wife understand his character ._____________]
# Bennet PERSON
# three NUMBER
# twenty years DURATION
# his PERSON
# his PERSON
# _           	_           	NFP   	O
# Her         	she         	PRP$  	O
# _           	_           	NFP   	O
# mind        	mind        	NN    	O
# was         	be          	VBD   	O
# less        	less        	RBR   	O
# difficult   	difficult   	JJ    	O
# to          	to          	TO    	O
# develope    	develope    	VB    	O
# .           	.           	.     	O
# [Sentence 58: _ Her _ mind was less difficult to develope ._____________]
# Her PERSON
# She         	she         	PRP   	O
# was         	be          	VBD   	O
# a           	a           	DT    	O
# woman       	woman       	NN    	O
# of          	of          	IN    	O
# mean        	mean        	JJ    	O
# understanding	understanding	NN    	O
# ,           	,           	,     	O
# little      	little      	JJ    	O
# information 	information 	NN    	O
# ,           	,           	,     	O
# and         	and         	CC    	O
# uncertain   	uncertain   	JJ    	O
# temper      	temper      	NN    	O
# .           	.           	.     	O
# [Sentence 59: She was a woman of mean understanding , little information , and uncertain temper ._____________]
# She PERSON
# When        	when        	WRB   	O
# she         	she         	PRP   	O
# was         	be          	VBD   	O
# discontented	discontented	JJ    	O
# she         	she         	PRP   	O
# fancied     	fancy       	VBD   	O
# herself     	herself     	PRP   	O
# nervous     	nervous     	JJ    	O
# .           	.           	.     	O
# [Sentence 60: When she was discontented she fancied herself nervous ._____________]
# she PERSON
# she PERSON
# The         	the         	DT    	O
# business    	business    	NN    	O
# of          	of          	IN    	O
# her         	she         	PRP$  	O
# life        	life        	NN    	O
# was         	be          	VBD   	O
# to          	to          	TO    	O
# get         	get         	VB    	O
# her         	she         	PRP$  	O
# daughters   	daughter    	NNS   	O
# married     	marry       	VBN   	O
# ;           	;           	:     	O
# its         	its         	PRP$  	O
# solace      	solace      	NN    	O
# was         	be          	VBD   	O
# visiting    	visit       	VBG   	O
# and         	and         	CC    	O
# news        	news        	NN    	O
# .           	.           	.     	O
# [Sentence 61: The business of her life was to get her daughters married ; its solace was visiting and news ._____________]
# her PERSON
# her PERSON
# time costing: 14.14368200302124
#
# The server should be stopped upon exit from the "with" statement.

# %%
# 字詞標註dataframe # 文章id, 字詞, 詞性還原, 詞性, 實體 
tokens.head()
# Out:
#    chapter       word      lemma  pos ner
# 0        0     TPRIDE     TPRIDE  NNP   O
# 1        0          &          &   CC   O
# 2        0  PREJUDICE  PREJUDICE  NNP   O
# 3        0          .          .    .   O
# 4        1         It         it  PRP   O

# %%
# 情緒分析dataframe # 文章id, 句子, 情緒
sentiment.head()
# Out:
#    chapter                                           sentence sentiment
# 0        0                               TPRIDE & PREJUDICE .   Neutral
# 1        1   It is a truth universally acknowledged , that...  Positive
# 2        1   However little known the feelings or views of...  Negative
# 3        1   " My dear Mr. Bennet , " said his lady to him...   Neutral
# 4        1               Mr. Bennet replied that he had not .  Negative

# %%
# 實體標註 dataframe # 文章id, 字詞, 實體
mention.head()
# Out:
#    chapter mention      ner
# 0        1   first  ORDINAL
# 1        1     one   NUMBER
# 2        1     his   PERSON
# 3        1      he   PERSON
# 4        1  Bennet   PERSON

# %%
# 檢查筆數正不正確
print(f"total posts numbers: {len(tokens['chapter'].unique())}") # 62 篇
print(f"posts sentiment: {len(sentiment['chapter'].unique())}") # 62 篇
print(f"posts have NER: {len(mention['chapter'].unique())}") # 61 篇有抓到ner
# Out:
# total posts numbers: 62
# posts sentiment: 62
# posts have NER: 61

# %%
# 儲存結果
tokens.to_csv('raw_data/eng/tokens_tp.csv', encoding = 'utf-8', index = False)
sentiment.to_csv('raw_data/eng/sentiment_tp.csv', encoding = 'utf-8', index = False)
mention.to_csv('raw_data/eng/mention_tp.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 3.2 探索分析 - NER
#
# 用NER實體標註的結果，探索這段時間關注covid19疫苗的國家、組織與人物，藉此找出這段時間的疫苗大事件。
#
# coreNLP_tokens_parser欄位:
# + status_id : 對應原本df裡的status_id，為一則tweets的唯一id
# + word: 原始斷詞
# + lemma : 對斷詞做詞形還原
# + pos : part-of-speech,詞性
# + ner: 命名實體

# %%
# 讀取已經執行完畢的結果
tokens = pd.read_csv('raw_data/eng/tokens_tp.csv')
mention = pd.read_csv('raw_data/eng/mention_tp.csv')
sentiment = pd.read_csv('raw_data/eng/sentiment_tp.csv')

# %%
tokens.head()
# Out:
#    chapter       word      lemma  pos ner
# 0        0     TPRIDE     TPRIDE  NNP   O
# 1        0          &          &   CC   O
# 2        0  PREJUDICE  PREJUDICE  NNP   O
# 3        0          .          .    .   O
# 4        1         It         it  PRP   O

# %%
mention.head()
# Out:
#    chapter mention      ner
# 0        1   first  ORDINAL
# 1        1     one   NUMBER
# 2        1     his   PERSON
# 3        1      he   PERSON
# 4        1  Bennet   PERSON

# %% [markdown]
# ### NER 種類分析
# 查看標註這個文集後辨識出哪一些實體種類

# %%
# 查看辨識出哪幾種NER
tokens['ner'].unique()
# Out:
# array(['O', 'ORDINAL', 'NUMBER', 'PERSON', 'DURATION', 'LOCATION',
#        'COUNTRY', 'DATE', 'TITLE', 'TIME', 'SET', 'CITY',
#        'STATE_OR_PROVINCE', 'ORGANIZATION', 'MONEY', 'MISC',
#        'NATIONALITY', 'CAUSE_OF_DEATH', 'RELIGION', 'IDEOLOGY',
#        'CRIMINAL_CHARGE'], dtype=object)

# %%
# 查看辨識出哪幾種NER
mention['ner'].unique()
# Out:
# array(['ORDINAL', 'NUMBER', 'PERSON', 'DURATION', 'LOCATION', 'COUNTRY',
#        'DATE', 'TITLE', 'TIME', 'SET', 'CITY', 'STATE_OR_PROVINCE',
#        'ORGANIZATION', 'MONEY', 'MISC', 'NATIONALITY', 'CAUSE_OF_DEATH',
#        'RELIGION', 'IDEOLOGY', 'CRIMINAL_CHARGE'], dtype=object)

# %%
# 'O' 代表 other，看看除了other，有幾個字有被標出 entity
len(tokens.loc[tokens['ner'] != 'O']['word'].unique()) # 417個字有被標出entity
# Out:
# 417

# %% [markdown]
# 可以發現以字為單位的`tokens`中的 NER 標記，會有`O`類別的標記，代表非NER的字詞，而`mention`則是以完整的名詞為單位，為了方便分析，我們使用`mention`中的結果進行統計

# %%
# 進行類別統計
ner_count = mention.groupby(['ner'])['ner'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(10)
ner_count
# Out:
#                   ner  count
# 14             PERSON  10660
# 4                DATE    663
# 11             NUMBER    568
# 7            LOCATION    331
# 5            DURATION    313
# 19              TITLE    284
# 17  STATE_OR_PROVINCE    249
# 1                CITY    203
# 18               TIME    172
# 12            ORDINAL    163

# %%
ner = ner_count['ner']
count = ner_count['count']

fig, ax = plt.subplots(figsize =(12, 7))
ax.barh(ner, count)
ax.invert_yaxis()
ax.set_title('ner Frequency',loc ='left', size = 16)
ax.set_ylabel('ner', size = 16)
ax.set_xlabel('Frequency', size = 16)
fig.show()
# Out:
# /var/folders/wb/4p2wtwfn0hbfl5wk9721_6gm0000gn/T/ipykernel_52005/972383025.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# 為了正確計算詞頻，將字詞轉小寫存新欄位

# %%
mention['word_lower'] = mention['mention'].str.lower()
mention.tail()
# Out:
#        chapter     mention                ner  word_lower
# 13852       61   Gardiners           LOCATION   gardiners
# 13853       61       Darcy             PERSON       darcy
# 13854       61   Elizabeth             PERSON   elizabeth
# 13855       61  Derbyshire  STATE_OR_PROVINCE  derbyshire
# 13856       61         her             PERSON         her

# %% [markdown]
# ### 涉及到的地點(LOCATION)
# + 透過coreNLP中的NER解析出在傲慢與偏見中所涉及到的地點(LOCATION)

# %%
# 篩選ner為country的資料
location = mention.loc[mention['ner'] == 'LOCATION']

# 計算每個地點提到的次數，選出前8個
location_count = location[['word_lower']].groupby(['word_lower'])['word_lower'].count().reset_index(name='count')
location_count = location_count.sort_values(['count'], ascending=False).head(8)
location_count
# Out:
#      word_lower  count
# 21    longbourn     74
# 27  netherfield     68
# 24      meryton     52
# 32    pemberley     30
# 34      rosings     20
# 15     hunsford     16
# 1       bingley     14
# 9   fitzwilliam     13

# %%
word = location_count['word_lower']
count = location_count['count']

fig, ax = plt.subplots(figsize =(12, 7))
ax.barh(word, count)
ax.invert_yaxis()
ax.set_title('Word Frequency (NER is LOCATION)',loc ='left', size = 16)
ax.set_ylabel('location', size = 16)
ax.set_xlabel('Word Frequency', size = 16)
fig.show()
# Out:
# /var/folders/wb/4p2wtwfn0hbfl5wk9721_6gm0000gn/T/ipykernel_52005/328278394.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# + 可以抓取關鍵字地點，看看相關的章節大致在說甚麼

# %%
keyword_list = ['hunsford']
ids = location[location['word_lower'].str.contains('|'.join(keyword_list),regex=True, case=False)].chapter
df = df_chapter[df_chapter['chapter'].isin(ids)]
print(f"{' '.join(keyword_list)}：{df.shape[0]}個相關章節")
df
# Out:
# hunsford：13個相關章節
#     chapter                                           sentence
# 15       15  Mr. Collins was not a sensible man, and the de...
# 19       19  The next day opened a new scene at Longbourn. ...
# 23       23  Elizabeth was sitting with her mother and sist...
# 26       26  Mrs. Gardiner's caution to Elizabeth was punct...
# 27       27  With no greater events than these in the Longb...
# 28       28  When they left the high road for the lane to H...
# 30       30  Sir William staid only a week at Hunsford; but...
# 32       32  Elizabeth was sitting by herself the next morn...
# 33       33  More than once did Elizabeth in her ramble wit...
# 37       37  The two gentlemen left Rosings the next mornin...
# 41       41  The first week of their return was soon gone. ...
# 43       43  The park was very large, and contained great v...
# 44       44  Elizabeth had settled it that Mr. Darcy would ...

# %% [markdown]
# ### 涉及到的城市(CITY)
# + 我們可以透過coreNLP中的NER解析出在傲慢與偏見中所涉及到的城市(CITY)

# %%
# 篩選ner為country的資料
city = mention.loc[mention['ner'] == 'CITY']

# 計算每個地點提到的次數，選出前8個
location_city = city[['word_lower']].groupby(['word_lower'])['word_lower'].count().reset_index(name='count')
location_city = location_city.sort_values(['count'], ascending=False).head(8)
location_city
# Out:
#       word_lower  count
# 3      charlotte     64
# 9         london     57
# 7  hertfordshire     41
# 1       brighton     24
# 8           kent      6
# 5          epsom      3
# 0     birmingham      1
# 2      cambridge      1

# %%
word = location_city['word_lower']
count = location_city['count']

fig, ax = plt.subplots(figsize =(12, 7))
ax.barh(word, count)
ax.invert_yaxis()
ax.set_title('Word Frequency (NER is CITY)',loc ='left', size = 16)
ax.set_ylabel('City', size = 16)
ax.set_xlabel('Word Frequency', size = 16)
fig.show()
# Out:
# /var/folders/wb/4p2wtwfn0hbfl5wk9721_6gm0000gn/T/ipykernel_52005/271953708.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 查看特定關鍵字的貼文內容
keyword_list = ['brighton']
ids = city[city['word_lower'].str.contains('|'.join(keyword_list),regex=True, case=False)].chapter
df = df_chapter[df_chapter['chapter'].isin(ids)]
print(f"{' '.join(keyword_list)}：{df.shape[0]}個相關章節")
df
# Out:
# brighton：7個相關章節
#     chapter                                           sentence
# 39       39  It was the second week in May, in which the th...
# 41       41  The first week of their return was soon gone. ...
# 46       46  Elizabeth had been a good deal disappointed in...
# 47       47  It appears to me so very unlikely, that any yo...
# 48       48  The whole party were in hopes of a letter from...
# 50       50  Mr. Bennet had very often wished, before this ...
# 51       51  Their sister's wedding day arrived; and Jane a...

# %% [markdown]
# ### 涉及到的人物(PERSON)
# + 我們可以透過coreNLP中的NER解析出在傲慢與偏見中所涉及到的人物(PERSON)
# + 有些人稱代名詞(personal pronoun) 像 her或 his， 在 `mention` 裡屬於 `PERSON` ，但應該更接近於 `token` 裡面的 `O`分類，在計算詞頻的時候把他們先過濾掉

# %%
# 查看 her 的 NER 分類 
keyword_list = ['her']
print("for ner:", tokens.loc[tokens['word'] == 'her'].ner.unique()) 
print("for entityMention:", mention.loc[mention['word_lower'] == 'her'].ner.unique())
# Out:
# for ner: ['O']
# for entityMention: ['PERSON']

# %%
peo = mention.loc[mention['ner'] == 'PERSON']

# 手動移除coreNLP分不好的字詞
remove_l = ['her','his','he','she','him']
peo = peo[~peo.word_lower.isin(remove_l)]

peo_count = peo[['word_lower']].groupby(['word_lower'])['word_lower'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(10)
peo_count.head()
# Out:
#    word_lower  count
# 29  elizabeth    611
# 21      darcy    412
# 5      bennet    301
# 51       jane    287
# 6     bingley    224

# %%
word = peo_count['word_lower']
count = peo_count['count']

fig, ax = plt.subplots(figsize =(12, 7))
ax.barh(word, count)
ax.invert_yaxis()
ax.set_title('Word Frequency (NER is PERSON)',loc ='left', size = 16)
ax.set_ylabel('person', size = 16)
ax.set_xlabel('Word Frequency', size = 16)
fig.show()
# Out:
# /var/folders/wb/4p2wtwfn0hbfl5wk9721_6gm0000gn/T/ipykernel_52005/3454232053.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# + Elizabeth: Elizabeth Bennet，傲慢與偏見女主角。
# + Darcy: Fitzwilliam Darcy，傲慢與偏見男主角，一位富有的紳士，英格蘭德比郡的大地主。
# + Collins: William Collins，班奈特先生的表親，自以為是、嘮叨而勢利的牧師。

# %%
# 查看特定關鍵字的貼文內容
keyword_list = ['collins']
ids = peo[peo['word_lower'].str.contains('|'.join(keyword_list),regex=True, case=False)].chapter
df = df_chapter[df_chapter['chapter'].isin(ids)]
print(f"{' '.join(keyword_list)}：{df.shape[0]}個相關章節")
df.head()
# Out:
# collins：30個相關章節
#     chapter                                           sentence
# 13       13  "I hope, my dear," said Mr. Bennet to his wife...
# 14       14  During dinner, Mr. Bennet scarcely spoke at al...
# 15       15  Mr. Collins was not a sensible man, and the de...
# 16       16  As no objection was made to the young people's...
# 17       17  Elizabeth related to Jane the next day, what h...

# %% [markdown]
# ### 3.3 探索分析 - Sentiment
# 將經過coreNLP處理後的文集，進行情緒分析

# %%
# 讀取已經執行完畢的結果
sentiment = pd.read_csv("raw_data/eng/sentiment_tp.csv")
sentiment.head(5)
# Out:
#    chapter                                           sentence sentiment
# 0        0                               TPRIDE & PREJUDICE .   Neutral
# 1        1   It is a truth universally acknowledged , that...  Positive
# 2        1   However little known the feelings or views of...  Negative
# 3        1   " My dear Mr. Bennet , " said his lady to him...   Neutral
# 4        1               Mr. Bennet replied that he had not .  Negative

# %%
# 看有哪些情緒
sentiment['sentiment'].unique()
# Out:
# array(['Neutral', 'Positive', 'Negative', 'Very positive',
#        'Very negative'], dtype=object)

# %%
# 看一下各情緒的分布
sentiment.groupby('sentiment')['sentiment'].agg(['count'])
# Out:
#                count
# sentiment
# Negative        2661
# Neutral         2046
# Positive        1318
# Very negative      2
# Very positive     20

# %%
# 將情緒轉為分數
def label_sentiment(row):
    if row['sentiment'] == "Very positive" :
        return 2
    if row['sentiment'] == "Positive" :
        return 1
    if row['sentiment'] == "Neutral" :
        return 0
    if row['sentiment'] == "Negative" :
        return -1
    if row['sentiment'] == "Very negative" :
        return -2

# %%
sentiment['sentimentValue'] = sentiment.apply(lambda row: label_sentiment(row), axis=1)
sentiment.head()
# Out:
#    chapter                                           sentence sentiment  \
# 0        0                               TPRIDE & PREJUDICE .   Neutral
# 1        1   It is a truth universally acknowledged , that...  Positive
# 2        1   However little known the feelings or views of...  Negative
# 3        1   " My dear Mr. Bennet , " said his lady to him...   Neutral
# 4        1               Mr. Bennet replied that he had not .  Negative
#
#    sentimentValue
# 0               0
# 1               1
# 2              -1
# 3               0
# 4              -1

# %% [markdown]
# + 平均情緒分數章節趨勢

# %%
# 算出各章節平均情緒分數
sentiment_count = sentiment.groupby(['chapter'])['sentimentValue'].mean().reset_index()
sentiment_count
# Out:
#     chapter  sentimentValue
# 0         0        0.000000
# 1         1       -0.163934
# 2         2       -0.433962
# 3         3       -0.079545
# 4         4       -0.054545
# ..      ...             ...
# 57       57       -0.278481
# 58       58       -0.313869
# 59       59       -0.038889
# 60       60       -0.116279
# 61       61       -0.146341
#
# [62 rows x 2 columns]

# %%
# 平均情緒分數時間趨勢
plt.plot(sentiment_count['chapter'].values, sentiment_count['sentimentValue'].values , linestyle='solid')
plt.xlabel('chapter') # x軸標題
plt.ylabel('sentiment value') # y軸標題
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 正面詞彙探索
# 把正面文章挑出來，看看他們都用甚麼詞

# %%
# 把 token 的字詞降大小寫
tokens['lemma_lower'] = tokens['lemma'].str.lower()

# %%
# 挑出正面詞彙
positive = sentiment[sentiment['sentiment'].isin(['Very positive'])]
positive
positive_words = pd.merge(positive,tokens,on='chapter',how='left')
positive_words.head()
# Out:
#    chapter                                           sentence      sentiment  \
# 0        3   she is the most beautiful creature I ever beh...  Very positive
# 1        3   she is the most beautiful creature I ever beh...  Very positive
# 2        3   she is the most beautiful creature I ever beh...  Very positive
# 3        3   she is the most beautiful creature I ever beh...  Very positive
# 4        3   she is the most beautiful creature I ever beh...  Very positive
#
#    sentimentValue    word   lemma  pos     ner lemma_lower
# 0               2     Not     not   RB       O         not
# 1               2     all     all   DT       O         all
# 2               2    that    that  WDT       O        that
# 3               2    Mrs.    Mrs.  NNP       O        mrs.
# 4               2  Bennet  Bennet  NNP  PERSON      bennet

# %%
# 匯入預設的stop words，也可以自訂
stop_words = set(stopwords.words('english'))
stop_words.update(["could", "would","might","may","_","must"])

# 可以設定字型大小和背景顏色
wordcloud = WordCloud(
                stopwords=stop_words,
                max_font_size=100, width=800, height = 400, background_color="white")\
                .generate(' '.join(positive_words['lemma_lower']))

# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation="bilinear")

plt.axis("off")
plt.show()

# %%
# 挑出負面詞彙
negative = sentiment[sentiment['sentiment'].isin(['Very negative'])]
negative_words = pd.merge(negative,tokens,on='chapter',how='left')
negative_words.head()
# Out:
#    chapter                                           sentence      sentiment  \
# 0        3   Mr. Darcy walked off ; and Elizabeth remained...  Very negative
# 1        3   Mr. Darcy walked off ; and Elizabeth remained...  Very negative
# 2        3   Mr. Darcy walked off ; and Elizabeth remained...  Very negative
# 3        3   Mr. Darcy walked off ; and Elizabeth remained...  Very negative
# 4        3   Mr. Darcy walked off ; and Elizabeth remained...  Very negative
#
#    sentimentValue    word   lemma  pos     ner lemma_lower
# 0              -2     Not     not   RB       O         not
# 1              -2     all     all   DT       O         all
# 2              -2    that    that  WDT       O        that
# 3              -2    Mrs.    Mrs.  NNP       O        mrs.
# 4              -2  Bennet  Bennet  NNP  PERSON      bennet

# %%
# 匯入預設的stop words 也可以自訂
stop_words = set(stopwords.words('english'))
stop_words.update(["could", "would","might","may","_"])

# 可以設定字型大小和背景顏色
wordcloud = WordCloud(
                stopwords=stop_words,
                max_font_size=100, width=800, height = 400, background_color="white")\
                .generate(' '.join(negative_words['lemma_lower']))

# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation="bilinear")

plt.axis("off")
plt.show()

# %% [markdown]
# 正負面文字雲相比之下，會發現特定人名如mr darcy多數出現在正面場景，而mr bingley在極度負面的場景中出現的比率非常高。

# %% [markdown]
# ## 4. TextBlob
#
# + 除了coreNLP 還有一些比較簡單的套件可以處理文字，在這裡介紹textBlob，https://github.com/sloria/TextBlob
# + 根據analyzer不同，可分為 lexicon-based 和 corpus-based 情緒分析
# + 情緒計算
#     + lexicon-based
#         + polarity > 0 是正面的字，反之是負面的
#         + subjectivity 代表有多主觀
#     + corpus-based
#         + classification 代表分類後的情緒為正面(pos)還是負面(neg)
#         + p_pos 代表positive的機率
#         + p_neg 代表negative的機率
# + 我們把正負面的貼文挑出來，然後再看看通常正負面的貼文都用什麼樣的字

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
# Corpus-based 的 TextBlob
# 獲得一個句子的情緒分類以及正負面情緒
testimonial = TextBlob("Textblob is amazingly simple to use. What great fun!", analyzer = NaiveBayesAnalyzer())
testimonial.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.861651708233218, p_neg=0.13834829176678198)

# %%
# Lexicon-based 的 TextBlob
# 獲得一個句子的正負面情緒以及主觀程度
testimonial = TextBlob("Textblob is amazingly simple to use. What great fun!")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.39166666666666666, subjectivity=0.4357142857142857)

# %% [markdown]
# 因為是lexicon-based，所以可以觀察 TextBlob 對於強調詞和否定詞的效果

# %%
testimonial = TextBlob("She looks gorgeous.")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.7, subjectivity=0.9)

# %%
# 新增強調詞: very
testimonial = TextBlob("She looks very gorgeous")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.9099999999999999, subjectivity=1.0)

# %%
# 新增否定詞: not
testimonial = TextBlob("She looks not very gorgeous")
testimonial.sentiment
# Out:
# Sentiment(polarity=-0.26923076923076916, subjectivity=0.6923076923076923)

# %%
# 也可以看到一樣的句子在 corpus-based 中並不會被判斷為負面
testimonial = TextBlob("She looks not very gorgeous", analyzer = NaiveBayesAnalyzer())
testimonial.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.5411926381089733, p_neg=0.45880736189102644)

# %% [markdown]
# 將傲慢與偏見套入 TextBlob，計算情緒

# %%
def sentiment_calc(text):
    try:
        return TextBlob(text).sentiment.polarity
    except:
        return None

df_chapter['polarity'] = df_chapter['sentence'].apply(sentiment_calc)
df_chapter
# Out:
#     chapter                                           sentence  polarity
# 0         0                               ﻿TPRIDE & PREJUDICE.  0.000000
# 1         1  It is a truth universally acknowledged, that a...  0.113349
# 2         2  Mr. Bennet was among the earliest of those who...  0.085062
# 3         3  Not all that Mrs. Bennet, however, with the as...  0.179997
# 4         4  When Jane and Elizabeth were alone, the former...  0.299587
# ..      ...                                                ...       ...
# 57       57  The discomposure of spirits, which this extrao...  0.143677
# 58       58  Instead of receiving any such letter of excuse...  0.064096
# 59       59  "My dear Lizzy, where can you have been walkin...  0.194092
# 60       60  Elizabeth's spirits soon rising to playfulness...  0.129241
# 61       61  Happy for all her maternal feelings was the da...  0.205059
#
# [62 rows x 3 columns]

# %%
# 挑出正負面情緒
positive = df_chapter.loc[df_chapter['polarity'] > 0][['chapter','polarity']]
negative = df_chapter.loc[df_chapter['polarity'] < 0][['chapter','polarity']]

# %%
positive
# Out:
#     chapter  polarity
# 1         1  0.113349
# 2         2  0.085062
# 3         3  0.179997
# 4         4  0.299587
# 5         5  0.206245
# ..      ...       ...
# 57       57  0.143677
# 58       58  0.064096
# 59       59  0.194092
# 60       60  0.129241
# 61       61  0.205059
#
# [61 rows x 2 columns]

# %%
# 去除停用字和標點符號
stop_words = set(stopwords.words('english'))
stop_words.update(["could", "would","might","may","_","must"])
filter_tokens = tokens[~tokens.word.isin(list(stop_words))] 
filter_tokens = filter_tokens[filter_tokens.lemma_lower.str.isalpha()]

# %%
filter_tokens.head(5)
# Out:
#    chapter         word        lemma  pos ner  lemma_lower
# 0        0       TPRIDE       TPRIDE  NNP   O       tpride
# 2        0    PREJUDICE    PREJUDICE  NNP   O    prejudice
# 4        1           It           it  PRP   O           it
# 7        1        truth        truth   NN   O        truth
# 8        1  universally  universally   RB   O  universally

# %%
positive_words = pd.merge(positive,filter_tokens[['chapter','lemma_lower']],on='chapter',how='left')

# %% [markdown]
# 看一下正面的句子都用甚麼樣的詞

# %%
positive_words.groupby(['lemma_lower'])['lemma_lower'] \
                         .count() \
                         .reset_index(name='count') \
                         .sort_values(['count'], ascending=False) \
                         .head(10)
# Out:
#      lemma_lower  count
# 2022           i   2067
# 1356   elizabeth    630
# 3519         say    610
# 983        darcy    418
# 3622         she    412
# 3563         see    389
# 2345        know    388
# 2494        make    335
# 4026       think    330
# 2650        much    327

# %% [markdown]
# ### 補充：其他英文處理套件

# %% [markdown]
# #### emoji
# +  emoji 轉英文字

# %%
# %pip install emoji

# %%
# emoji to text
import emoji 
print(emoji.demojize('Python is 👍'))
# Out:
# Python is :thumbs_up:

# %% [markdown]
# #### vaderSentiment
# + 分析英文句子情緒

# %%
# %pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

# --- examples -------
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled
             "Not bad at all"  # Capitalized negation
             ]

analyzer = SentimentIntensityAnalyzer()
for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# VADER is smart, handsome, and funny.----------------------------- {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}
# VADER is smart, handsome, and funny!----------------------------- {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439}
# At least it isn't a horrible book.------------------------------- {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.431}
# The book was only kind of good.---------------------------------- {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.3832}
# The plot was good, but the characters are uncompelling and the dialog is not great. {'neg': 0.327, 'neu': 0.579, 'pos': 0.094, 'compound': -0.7042}
# Today SUX!------------------------------------------------------- {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# Today only kinda sux! But I'll get by, lol----------------------- {'neg': 0.127, 'neu': 0.556, 'pos': 0.317, 'compound': 0.5249}
# Make sure you :) or :D today!------------------------------------ {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}
# Catch utf-8 emoji such as such as 💘 and 💋 and 😁------------------ {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.875}
# Not bad at all--------------------------------------------------- {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.431}

# %% [markdown]
# #### sentimentpy
# + github: https://github.com/trinker/sentimentpy
# + 請用這種方式安裝 `pip install git+https://github.com/trinker/sentimentpy`

# %%
# %pip install git+https://github.com/trinker/sentimentpy

# %%
# 把句子斷開，去除結尾空白符號
import sentimentpy.split_sentences as ss

s = [
    'I like carrots too mrs. dunbar. Well let\'s go to 100th st. around the corner.   ',
    'Hello Dr. Livingstone.  How are you?',
    'This is sill an incomplete thou.'
]

ss.split_sentences(s)
# Out:
# /usr/local/anaconda3/envs/test/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# ['I like carrots too mrs. dunbar.',
#  "Well let's go to 100th st. around the corner.",
#  'Hello Dr. Livingstone.',
#  'How are you?',
#  'This is sill an incomplete thou.']
